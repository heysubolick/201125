# %% [markdown]
# ▷ 이번년도 서울 도시안전 예산 1조 5,280억원(4.3%)
#
# 시설물 관리 7,970억원 / 수방 및 치수 5,341억원 / 소방안전 1,969억원

# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 서울열린데이터 광장
# - 서울시 자치구별 cctv 대수
# - https://data.seoul.go.kr/dataList/OA-2734/C/1/datasetView.do

# %%
df2 = pd.read_csv('cctv.csv')
df2.head()
# Out:
#      기관명       소계 2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구   5,221    1,944   195.0  316.0   430   546.0  765.0  577.0  448.0
# 1  강 동 구   1,879      303   387.0  134.0    59   144.0  194.0  273.0  385.0
# 2  강 북 구   1,265      243    88.0  141.0    74   145.0  254.0    1.0  319.0
# 3  강 서 구   1,617      219   155.0  118.0   230   187.0  190.0  264.0  254.0
# 4  관 악 구   3,985      430    56.0  419.0   487   609.0  619.0  694.0  671.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   기관명       25 non-null     object
#  1   소계        25 non-null     object
#  2   2011년 이전  23 non-null     object
#  3   2012년     23 non-null     float64
#  4   2013년     23 non-null     float64
#  5   2014년     25 non-null     object
#  6   2015년     25 non-null     float64
#  7   2016년     25 non-null     float64
#  8   2017년     25 non-null     float64
#  9   2018년     25 non-null     float64
# dtypes: float64(6), object(4)
# memory usage: 2.3+ KB

# %%
df2['소계'] = df2['소계'].str.replace(',', '')
df2['2014년'] = df2['2014년'].str.replace(',', '')
df2['2014년'] = df2['2014년'].astype(float)

# %%
df2.columns
# Out:
# Index(['기관명', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년'],
#       dtype='object')

# %%
df2_sample = df2.loc[:,['기관명','소계','2014년','2015년','2016년','2017년','2018년']]
df2_sample
# Out:
#         기관명      소계   2014년  2015년  2016년  2017년  2018년
# 0     강 남 구   5221    430.0  546.0  765.0  577.0  448.0
# 1     강 동 구   1879     59.0  144.0  194.0  273.0  385.0
# 2     강 북 구   1265     74.0  145.0  254.0    1.0  319.0
# 3     강 서 구   1617    230.0  187.0  190.0  264.0  254.0
# 4     관 악 구   3985    487.0  609.0  619.0  694.0  671.0
# 5     광 진 구   1581     87.0   64.0   21.0  468.0  346.0
# 6     구 로 구   3227    187.0  268.0  326.0  540.0  486.0
# 7     금 천 구   1634    101.0  382.0  136.0  199.0  530.0
# 8     노 원 구   1906     80.0  461.0  298.0  110.0  156.0
# 9     도 봉 구    858    185.0   59.0  155.0  117.0   71.0
# 10     동대문구   2003   1326.0  111.0  233.0  136.0  197.0
# 11    동 작 구   1780    503.0  130.0  254.0  278.0  255.0
# 12    마 포 구   1935     70.0  177.0  359.0  372.0  195.0
# 13     서대문구   2121    114.0  109.0  277.0  415.0  194.0
# 14    서 초 구   2835    134.0  215.0  352.0  247.0  396.0
# 15    성 동 구   2679    101.0  258.0  201.0  933.0  294.0
# ...

# %%
df2_sample[df2_sample['기관명'].isnull()]
# Out:
#     기관명   소계  2014년  2015년  2016년  2017년  2018년
# 25  NaN  NaN    NaN    NaN    NaN    NaN    NaN
# 26  NaN  NaN    NaN    NaN    NaN    NaN    NaN
# 27  NaN  NaN    NaN    NaN    NaN    NaN    NaN

# %%
df2_sample.drop([25,26,27],inplace=True)

# %%
df2_sample['cctv합계'] = df2['2014년']+df2['2015년']+df2['2016년']+df2['2017년']+df2['2018년']

# %%
df2_sample
# Out:
#         기관명      소계   2014년  2015년  2016년  2017년  2018년  cctv합계
# 0     강 남 구   5221    430.0  546.0  765.0  577.0  448.0  2766.0
# 1     강 동 구   1879     59.0  144.0  194.0  273.0  385.0  1055.0
# 2     강 북 구   1265     74.0  145.0  254.0    1.0  319.0   793.0
# 3     강 서 구   1617    230.0  187.0  190.0  264.0  254.0  1125.0
# 4     관 악 구   3985    487.0  609.0  619.0  694.0  671.0  3080.0
# 5     광 진 구   1581     87.0   64.0   21.0  468.0  346.0   986.0
# 6     구 로 구   3227    187.0  268.0  326.0  540.0  486.0  1807.0
# 7     금 천 구   1634    101.0  382.0  136.0  199.0  530.0  1348.0
# 8     노 원 구   1906     80.0  461.0  298.0  110.0  156.0  1105.0
# 9     도 봉 구    858    185.0   59.0  155.0  117.0   71.0   587.0
# 10     동대문구   2003   1326.0  111.0  233.0  136.0  197.0  2003.0
# 11    동 작 구   1780    503.0  130.0  254.0  278.0  255.0  1420.0
# 12    마 포 구   1935     70.0  177.0  359.0  372.0  195.0  1173.0
# 13     서대문구   2121    114.0  109.0  277.0  415.0  194.0  1109.0
# ...

# %%
df2_sample.rename(columns={df2_sample.columns[0]:'구별'},inplace=True)

# %%
df2_sample
# Out:
#          구별      소계   2014년  2015년  2016년  2017년  2018년  cctv합계
# 0     강 남 구   5221    430.0  546.0  765.0  577.0  448.0  2766.0
# 1     강 동 구   1879     59.0  144.0  194.0  273.0  385.0  1055.0
# 2     강 북 구   1265     74.0  145.0  254.0    1.0  319.0   793.0
# 3     강 서 구   1617    230.0  187.0  190.0  264.0  254.0  1125.0
# 4     관 악 구   3985    487.0  609.0  619.0  694.0  671.0  3080.0
# 5     광 진 구   1581     87.0   64.0   21.0  468.0  346.0   986.0
# 6     구 로 구   3227    187.0  268.0  326.0  540.0  486.0  1807.0
# 7     금 천 구   1634    101.0  382.0  136.0  199.0  530.0  1348.0
# 8     노 원 구   1906     80.0  461.0  298.0  110.0  156.0  1105.0
# 9     도 봉 구    858    185.0   59.0  155.0  117.0   71.0   587.0
# 10     동대문구   2003   1326.0  111.0  233.0  136.0  197.0  2003.0
# 11    동 작 구   1780    503.0  130.0  254.0  278.0  255.0  1420.0
# 12    마 포 구   1935     70.0  177.0  359.0  372.0  195.0  1173.0
# 13     서대문구   2121    114.0  109.0  277.0  415.0  194.0  1109.0
# ...

# %%
import matplotlib as mpl
mpl.rc('font', family = 'Malgun Gothic')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# 구별 CCTV 합계를 그래프화
mpl.rc('font', family = 'Malgun Gothic')
sns.barplot(x = df2_sample['cctv합계'], y=df2_sample['구별'], data=df2_sample)
plt.show()

# %% [markdown]
# ### 서울열린데이터 광장
# - 서울시 5대범죄 발생현황
# - https://data.seoul.go.kr/dataList/316/C/2/datasetView.do

# %%
# CCTV수와 범죄발생 현황과의 연관성
# 범죄 발생 데이터
report = pd.read_csv('D:\\Group\\report.csv', sep='\t')

# %%
report
# Out:
#        기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0      기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1    2014   합계  130,674  79,061  158  152  343  299  5,462    4,957  59,393
# 2    2014  종로구    5,021   4,610    3    7   12   15    226      948   2,272
# 3    2014   중구    5,231   3,188    6    5   13   13    221      161   2,576
# 4    2014  용산구    3,799   2,340    1    2    7    7    213      169   1,560
# ..    ...  ...      ...     ...  ...  ...  ...  ...    ...      ...     ...
# 152  2019  관악구    5,328   3,810   13   10   10   11    408      335   2,223
# 153  2019  서초구    5,542   3,750    5    5    7    5    616      412   2,270
# 154  2019  강남구    7,304   5,069    5    3    5    6    666      562   2,970
# 155  2019  송파구    5,698   3,799    7    8   10   10    273      230   2,416
# 156  2019  강동구    4,014   2,955    6    5   15   14    180      155   1,650
#
#        절도.1      폭력    폭력.1
# ...

# %%
report2 = report.drop(0)

# %%
report2
# Out:
#        기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 1    2014   합계  130,674  79,061  158  152  343  299  5,462    4,957  59,393
# 2    2014  종로구    5,021   4,610    3    7   12   15    226      948   2,272
# 3    2014   중구    5,231   3,188    6    5   13   13    221      161   2,576
# 4    2014  용산구    3,799   2,340    1    2    7    7    213      169   1,560
# 5    2014  성동구    3,582   2,048    1    1    5    6    141      103   1,753
# ..    ...  ...      ...     ...  ...  ...  ...  ...    ...      ...     ...
# 152  2019  관악구    5,328   3,810   13   10   10   11    408      335   2,223
# 153  2019  서초구    5,542   3,750    5    5    7    5    616      412   2,270
# 154  2019  강남구    7,304   5,069    5    3    5    6    666      562   2,970
# 155  2019  송파구    5,698   3,799    7    8   10   10    273      230   2,416
# 156  2019  강동구    4,014   2,955    6    5   15   14    180      155   1,650
#
#        절도.1      폭력    폭력.1
# ...

# %%
report2.rename(columns={report2.columns[2]:'발생 합계',
                       report2.columns[3]:'검거 합계',
                       report2.columns[4]:'살인 발생',
                       report2.columns[5]:'살인 검거',
                       report2.columns[6]:'강도 발생',
                       report2.columns[7]:'강도 검거',
                       report2.columns[8]:'강간강제추행 발생',
                       report2.columns[9]:'강간강제추행 검거',
                       report2.columns[10]:'절도 발생',
                       report2.columns[11]:'절도 검거',
                       report2.columns[12]:'폭력 발생',
                       report2.columns[13]:'폭력 검거'}, inplace=True)
report2.head()
# Out:
#      기간  자치구    발생 합계   검거 합계 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 1  2014   합계  130,674  79,061   158   152   343   299     5,462     4,957
# 2  2014  종로구    5,021   4,610     3     7    12    15       226       948
# 3  2014   중구    5,231   3,188     6     5    13    13       221       161
# 4  2014  용산구    3,799   2,340     1     2     7     7       213       169
# 5  2014  성동구    3,582   2,048     1     1     5     6       141       103
#
#     절도 발생   절도 검거   폭력 발생   폭력 검거
# 1  59,393  19,120  65,318  54,533
# 2   2,272   1,281   2,508   2,359
# 3   2,576     887   2,415   2,122
# 4   1,560     522   2,018   1,640
# 5   1,753     529   1,682   1,409

# %%
report2.sort_values(by='자치구',ascending=True).head(10)
# Out:
#        기간  자치구  발생 합계  검거 합계 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 154  2019  강남구  7,304  5,069     5     3     5     6       666       562
# 128  2018  강남구  7,513  5,196    10    13    14    10       600       523
# 102  2017  강남구  7,720  5,321     7     7    20    24       607       496
# 76   2016  강남구  8,149  5,905     5     5    39    42       516       413
# 50   2015  강남구  8,617  5,732    13    10    21    18       449       349
# 24   2014  강남구  8,851  5,262    13     9    37    29       512       403
# 78   2016  강동구  4,462  3,273     4     5    14    13       160       152
# 130  2018  강동구  3,919  2,789     3     3     7     7       170       143
# 104  2017  강동구  4,261  3,245     5     6    10    12       172       169
# 52   2015  강동구  5,244  3,171     4     3     6     8       156       123
#
#      절도 발생  절도 검거  폭력 발생  폭력 검거
# 154  2,970  1,339  3,658  3,159
# 128  3,004  1,317  3,885  3,333
# 102  3,130  1,383  3,956  3,411
# 76   3,587  1,918  4,002  3,527
# ...

# %%
# CCTV 데이터가 2014~2018년 -> 값을 맞춰주기 위해 2019년 제거
idx_2019 = report2[report2['기간'] == '2019'].index
report3 = report2.drop(idx_2019)
report3
# Out:
#        기간  자치구    발생 합계   검거 합계 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 1    2014   합계  130,674  79,061   158   152   343   299     5,462     4,957
# 2    2014  종로구    5,021   4,610     3     7    12    15       226       948
# 3    2014   중구    5,231   3,188     6     5    13    13       221       161
# 4    2014  용산구    3,799   2,340     1     2     7     7       213       169
# 5    2014  성동구    3,582   2,048     1     1     5     6       141       103
# ..    ...  ...      ...     ...   ...   ...   ...   ...       ...       ...
# 126  2018  관악구    5,026   3,653     9     9    10    12       352       305
# 127  2018  서초구    4,726   3,183     5     5     5     5       470       315
# 128  2018  강남구    7,513   5,196    10    13    14    10       600       523
# 129  2018  송파구    5,807   4,051     5     6     6     8       309       254
# 130  2018  강동구    3,919   2,789     3     3     7     7       170       143
#
#       절도 발생   절도 검거   폭력 발생   폭력 검거
# ...

# %%
report4 = report3.sort_values(by=['자치구', '기간'], ascending=True)
report4
# Out:
#        기간  자치구    발생 합계   검거 합계 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 24   2014  강남구    8,851   5,262    13     9    37    29       512       403
# 50   2015  강남구    8,617   5,732    13    10    21    18       449       349
# 76   2016  강남구    8,149   5,905     5     5    39    42       516       413
# 102  2017  강남구    7,720   5,321     7     7    20    24       607       496
# 128  2018  강남구    7,513   5,196    10    13    14    10       600       523
# ..    ...  ...      ...     ...   ...   ...   ...   ...       ...       ...
# 1    2014   합계  130,674  79,061   158   152   343   299     5,462     4,957
# 27   2015   합계  126,401  82,680   163   156   276   257     5,449     5,069
# 53   2016   합계  117,839  84,421   148   147   262   257     6,002     5,565
# 79   2017   합계  107,835  79,865   142   140   169   170     6,963     6,558
# 105  2018   합계  101,948  74,487   143   139   143   151     6,412     6,046
#
#       절도 발생   절도 검거   폭력 발생   폭력 검거
# ...

# %%
report4.values
# Out:
# array([['2014', '강남구', '8,851', ..., '1,193', '4,394', '3,628'],
#        ['2015', '강남구', '8,617', ..., '1,650', '4,284', '3,705'],
#        ['2016', '강남구', '8,149', ..., '1,918', '4,002', '3,527'],
#        ...,
#        ['2016', '합계', '117,839', ..., '22,566', '64,570', '55,886'],
#        ['2017', '합계', '107,835', ..., '21,421', '59,399', '51,576'],
#        ['2018', '합계', '101,948', ..., '19,762', '56,075', '48,389']],
#       dtype=object)

# %%
report4.columns
# Out:
# Index(['기간', '자치구', '발생 합계', '검거 합계', '살인 발생', '살인 검거', '강도 발생', '강도 검거',
#        '강간강제추행 발생', '강간강제추행 검거', '절도 발생', '절도 검거', '폭력 발생', '폭력 검거'],
#       dtype='object')

# %%
report4['발생 합계'] = report4['발생 합계'].str.replace(',',"")
# report4['발생 합계'].astype(int)
report4['검거 합계'] = report4['검거 합계'].str.replace(',',"")
# report4['검거 합계'].astype(int)
report4['강간강제추행 발생'] = report4['강간강제추행 발생'].str.replace(',','')
report4['강간강제추행 검거'] = report4['강간강제추행 검거'].str.replace(',','')
report4['절도 발생'] = report4['절도 발생'].str.replace(',',"")
report4['절도 검거'] = report4['절도 검거'].str.replace(',',"")
report4['폭력 발생'] = report4['폭력 발생'].str.replace(',',"")
report4['폭력 검거'] = report4['폭력 검거'].str.replace(',',"")

# %%
report4.values
# Out:
# array([['2014', '강남구', '8851', ..., '1193', '4394', '3628'],
#        ['2015', '강남구', '8617', ..., '1650', '4284', '3705'],
#        ['2016', '강남구', '8149', ..., '1918', '4002', '3527'],
#        ...,
#        ['2016', '합계', '117839', ..., '22566', '64570', '55886'],
#        ['2017', '합계', '107835', ..., '21421', '59399', '51576'],
#        ['2018', '합계', '101948', ..., '19762', '56075', '48389']],
#       dtype=object)

# %%
report4
# Out:
#        기간  자치구   발생 합계  검거 합계 살인 발생 살인 검거 강도 발생 강도 검거 강간강제추행 발생 강간강제추행 검거  \
# 24   2014  강남구    8851   5262    13     9    37    29       512       403
# 50   2015  강남구    8617   5732    13    10    21    18       449       349
# 76   2016  강남구    8149   5905     5     5    39    42       516       413
# 102  2017  강남구    7720   5321     7     7    20    24       607       496
# 128  2018  강남구    7513   5196    10    13    14    10       600       523
# ..    ...  ...     ...    ...   ...   ...   ...   ...       ...       ...
# 1    2014   합계  130674  79061   158   152   343   299      5462      4957
# 27   2015   합계  126401  82680   163   156   276   257      5449      5069
# 53   2016   합계  117839  84421   148   147   262   257      6002      5565
# 79   2017   합계  107835  79865   142   140   169   170      6963      6558
# 105  2018   합계  101948  74487   143   139   143   151      6412      6046
#
#      절도 발생  절도 검거  폭력 발생  폭력 검거
# 24    3895   1193   4394   3628
# ...

# %%
report5 = report4.astype({'기간':int, '발생 합계':int, '검거 합계':int, '살인 발생':int, 
                          '살인 검거':int, '강도 발생':int, '강도 검거':int, 
                          '강간강제추행 발생':int, '강간강제추행 검거':int, 
                          '절도 발생':int, '절도 검거':int, '폭력 발생':int, '폭력 검거':int})
report5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 24 to 105
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기간         130 non-null    int32
#  1   자치구        130 non-null    object
#  2   발생 합계      130 non-null    int32
#  3   검거 합계      130 non-null    int32
#  4   살인 발생      130 non-null    int32
#  5   살인 검거      130 non-null    int32
#  6   강도 발생      130 non-null    int32
#  7   강도 검거      130 non-null    int32
#  8   강간강제추행 발생  130 non-null    int32
#  9   강간강제추행 검거  130 non-null    int32
#  10  절도 발생      130 non-null    int32
#  11  절도 검거      130 non-null    int32
#  12  폭력 발생      130 non-null    int32
#  13  폭력 검거      130 non-null    int32
# dtypes: int32(13), object(1)
# memory usage: 8.6+ KB

# %%
report5
# Out:
#        기간  자치구   발생 합계  검거 합계  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  \
# 24   2014  강남구    8851   5262     13      9     37     29        512
# 50   2015  강남구    8617   5732     13     10     21     18        449
# 76   2016  강남구    8149   5905      5      5     39     42        516
# 102  2017  강남구    7720   5321      7      7     20     24        607
# 128  2018  강남구    7513   5196     10     13     14     10        600
# ..    ...  ...     ...    ...    ...    ...    ...    ...        ...
# 1    2014   합계  130674  79061    158    152    343    299       5462
# 27   2015   합계  126401  82680    163    156    276    257       5449
# 53   2016   합계  117839  84421    148    147    262    257       6002
# 79   2017   합계  107835  79865    142    140    169    170       6963
# 105  2018   합계  101948  74487    143    139    143    151       6412
#
#      강간강제추행 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 24         403   3895   1193   4394   3628
# 50         349   3850   1650   4284   3705
# ...

# %%
# 히트맵으로 찍어보기 위해 의미없는 데이터인 합계 제거
reppp = report5
합계 = reppp[reppp['자치구'] == '합계'].index
repp = reppp.drop(합계)
repp
# Out:
#        기간  자치구  발생 합계  검거 합계  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  \
# 24   2014  강남구   8851   5262     13      9     37     29        512
# 50   2015  강남구   8617   5732     13     10     21     18        449
# 76   2016  강남구   8149   5905      5      5     39     42        516
# 102  2017  강남구   7720   5321      7      7     20     24        607
# 128  2018  강남구   7513   5196     10     13     14     10        600
# ..    ...  ...    ...    ...    ...    ...    ...    ...        ...
# 8    2014  중랑구   5353   3259     11     10     14     11        163
# 34   2015  중랑구   5193   3405     13     12     11      9        187
# 60   2016  중랑구   5041   3935      8      7     14     14        164
# 86   2017  중랑구   4571   3392      5      5      3      4        172
# 112  2018  중랑구   4288   3222      4      5      3      3        174
#
#      강간강제추행 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 24         403   3895   1193   4394   3628
# 50         349   3850   1650   4284   3705
# ...

# %%
# 히트맵으로 시각화하기 위해선 피봇 테이블로 우선 변경이 필요
report_pivot = repp.pivot('자치구', '기간', '발생 합계')
report_pivot
# Out:
# 기간    2014  2015  2016  2017  2018
# 자치구
# 강남구   8851  8617  8149  7720  7513
# 강동구   5392  5244  4462  4261  3919
# 강북구   4030  4257  4229  3393  3437
# 강서구   5289  5585  5450  5135  4629
# 관악구   6781  6345  5678  5525  5026
# 광진구   6268  5909  5322  4646  3915
# 구로구   5389  5646  5366  4895  4810
# 금천구   3842  3781  3645  3265  3293
# 노원구   5312  5130  4543  4209  4007
# 도봉구   3124  2664  2438  1999  2249
# 동대문구  4363  4720  4787  3975  3680
# 동작구   3869  4074  3227  3330  3100
# 마포구   5740  5854  5873  5278  5172
# 서대문구  4194  4029  3665  3113  2802
# 서초구   5558  5444  4989  4708  4726
# 성동구   3582  3358  3026  2767  2457
# 성북구   4606  4154  3744  3434  3042
# 송파구   8004  6778  6090  5576  5807
# 양천구   4642  4528  4112  3882  3515
# 영등포구  7003  6867  6322  5969  5840
# 용산구   3799  3820  4137  4060  3411
# 은평구   5431  4745  4501  3883  3590
# 종로구   5021  4705  4459  4057  3690
# 중구    5231  4954  4584  4184  4030
# 중랑구   5353  5193  5041  4571  4288

# %%
plt.figure(figsize=(10,10))
plt.title('서울시 자치구별 범죄 발생 히트맵', fontsize=30)
sns.heatmap(report_pivot, cmap='YlGnBu', annot = True, fmt='d')
plt.show()

# %%
# 2014~2018년 총합 -> 강남구를 예로 실행
강남 = report5.loc[report5["자치구"] == "강남구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
강남
# Out:
# 발생 합계        40850
# 검거 합계        27416
# 살인 발생           48
# 살인 검거           44
# 강도 발생          131
# 강도 검거          123
# 강간강제추행 발생     2684
# 강간강제추행 검거     2184
# 절도 발생        17466
# 절도 검거         7461
# 폭력 발생        20521
# 폭력 검거        17604
# dtype: int64

# %%
강남 = pd.DataFrame(강남)

# %%
강남
# Out:
#                0
# 발생 합계      40850
# 검거 합계      27416
# 살인 발생         48
# 살인 검거         44
# 강도 발생        131
# 강도 검거        123
# 강간강제추행 발생   2684
# 강간강제추행 검거   2184
# 절도 발생      17466
# 절도 검거       7461
# 폭력 발생      20521
# 폭력 검거      17604

# %%
강남.columns=['강남 총계']
강남
# Out:
#            강남 총계
# 발생 합계      40850
# 검거 합계      27416
# 살인 발생         48
# 살인 검거         44
# 강도 발생        131
# 강도 검거        123
# 강간강제추행 발생   2684
# 강간강제추행 검거   2184
# 절도 발생      17466
# 절도 검거       7461
# 폭력 발생      20521
# 폭력 검거      17604

# %%
강동 = report5.loc[report5["자치구"] == "강동구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
강북 = report5.loc[report5["자치구"] == "강북구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
강서 = report5.loc[report5["자치구"] == "강서구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
관악 = report5.loc[report5["자치구"] == "관악구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
광진 = report5.loc[report5["자치구"] == "광진구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
구로 = report5.loc[report5["자치구"] == "구로구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
금천 = report5.loc[report5["자치구"] == "금천구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
노원 = report5.loc[report5["자치구"] == "노원구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
도봉 = report5.loc[report5["자치구"] == "도봉구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
동대문 = report5.loc[report5["자치구"] == "동대문구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
동작 = report5.loc[report5["자치구"] == "동작구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
마포 = report5.loc[report5["자치구"] == "마포구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
서대문 = report5.loc[report5["자치구"] == "서대문구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
서초 = report5.loc[report5["자치구"] == "서초구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
성동 = report5.loc[report5["자치구"] == "성동구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
성북 = report5.loc[report5["자치구"] == "성북구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
송파 = report5.loc[report5["자치구"] == "송파구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
양천 = report5.loc[report5["자치구"] == "양천구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
영등포 = report5.loc[report5["자치구"] == "영등포구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
용산 = report5.loc[report5["자치구"] == "용산구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
은평 = report5.loc[report5["자치구"] == "은평구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
종로 = report5.loc[report5["자치구"] == "종로구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
중구 = report5.loc[report5["자치구"] == "중구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()
중랑 = report5.loc[report5["자치구"] == "중랑구", ["발생 합계", '검거 합계', '살인 발생', '살인 검거',
                                     '강도 발생', '강도 검거', '강간강제추행 발생', '강간강제추행 검거',
                                     '절도 발생', '절도 검거', '폭력 발생', '폭력 검거']].sum()

# %%
강동 = pd.DataFrame(강동)
강북 = pd.DataFrame(강북)
강서 = pd.DataFrame(강서)
관악 = pd.DataFrame(관악)
광진 = pd.DataFrame(광진)
구로 = pd.DataFrame(구로)
금천 = pd.DataFrame(금천)
노원 = pd.DataFrame(노원)
도봉 = pd.DataFrame(도봉)
동대문 = pd.DataFrame(동대문)
동작 = pd.DataFrame(동작)
마포 = pd.DataFrame(마포)
서대문 = pd.DataFrame(서대문)
서초 = pd.DataFrame(서초)
성동 = pd.DataFrame(성동)
성북 = pd.DataFrame(성북)
송파 = pd.DataFrame(송파)
양천 = pd.DataFrame(양천)
영등포 = pd.DataFrame(영등포)
용산 = pd.DataFrame(용산)
은평 = pd.DataFrame(은평)
종로 = pd.DataFrame(종로)
중구 = pd.DataFrame(중구)
중랑 = pd.DataFrame(중랑)

# %%
강동.columns=['강동 총계']
강북.columns=['강북 총계']
강서.columns=['강서 총계']
관악.columns=['관악 총계']
광진.columns=['광진 총계']
구로.columns=['구로 총계']
금천.columns=['금천 총계']
노원.columns=['노원 총계']
도봉.columns=['도봉 총계']
동대문.columns=['동대문 총계']
동작.columns=['동작 총계']
마포.columns=['마포 총계']
서대문.columns=['서대문 총계']
서초.columns=['서초 총계']
성동.columns=['성동 총계']
성북.columns=['성북 총계']
송파.columns=['송파 총계']
양천.columns=['양천 총계']
영등포.columns=['영등포 총계']
용산.columns=['용산 총계']
은평.columns=['은평 총계']
종로.columns=['종로 총계']
중구.columns=['중구 총계']
중랑.columns=['중랑 총계']

# %%
result = pd.concat([강남, 강동, 강북, 강서, 관악, 광진, 구로, 금천, 노원, 도봉, 동대문, 동작, 마포, 서대문,
                 서초, 성동, 성북, 송파, 양천, 영등포, 용산, 은평, 종로, 중구, 중랑], axis=1)

# %%
result
# Out:
#            강남 총계  강동 총계  강북 총계  강서 총계  관악 총계  광진 총계  구로 총계  금천 총계  노원 총계  \
# 발생 합계      40850  23278  19346  26088  29355  26060  26106  17826  23201
# 검거 합계      27416  15763  14809  18908  19145  16628  16977  13125  15361
# 살인 발생         48     21     36     46     39     29     35     27     29
# 살인 검거         44     21     33     44     39     27     34     28     28
# 강도 발생        131     47     54     42     66     56     56     34     35
# 강도 검거        123     48     39     41     64     63     49     30     35
# 강간강제추행 발생   2684    806    955   1336   1734   1258   1384    928    903
# 강간강제추행 검거   2184    716    725   1108   1351   1045    893    795    727
# 절도 발생      17466   9705   6276  10001  11829  12818  10064   6692   9414
# 절도 검거       7461   4232   3103   5159   4725   5477   3985   3357   3686
# 폭력 발생      20521  12699  12025  14663  15687  11899  14567  10145  12820
# 폭력 검거      17604  10746  10909  12556  12966  10016  12016   8915  10885
#
# ...

# %%
# 행과 열을 바꿈
df = result.transpose()
df
# Out:
#         발생 합계  검거 합계  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  강간강제추행 검거  절도 발생  \
# 강남 총계   40850  27416     48     44    131    123       2684       2184  17466
# 강동 총계   23278  15763     21     21     47     48        806        716   9705
# 강북 총계   19346  14809     36     33     54     39        955        725   6276
# 강서 총계   26088  18908     46     44     42     41       1336       1108  10001
# 관악 총계   29355  19145     39     39     66     64       1734       1351  11829
# 광진 총계   26060  16628     29     27     56     63       1258       1045  12818
# 구로 총계   26106  16977     35     34     56     49       1384        893  10064
# 금천 총계   17826  13125     27     28     34     30        928        795   6692
# 노원 총계   23201  15361     29     28     35     35        903        727   9414
# 도봉 총계   12474   9144     14     15     33     36        614        618   4693
# 동대문 총계  21525  15952     35     33     44     42        814        677   8724
# ...

# %%
# 인덱싱 다시 함
data = df.reset_index().rename(columns={"index": "구별"})
data
# Out:
#         구별  발생 합계  검거 합계  살인 발생  살인 검거  강도 발생  강도 검거  강간강제추행 발생  강간강제추행 검거  \
# 0    강남 총계  40850  27416     48     44    131    123       2684       2184
# 1    강동 총계  23278  15763     21     21     47     48        806        716
# 2    강북 총계  19346  14809     36     33     54     39        955        725
# 3    강서 총계  26088  18908     46     44     42     41       1336       1108
# 4    관악 총계  29355  19145     39     39     66     64       1734       1351
# 5    광진 총계  26060  16628     29     27     56     63       1258       1045
# 6    구로 총계  26106  16977     35     34     56     49       1384        893
# 7    금천 총계  17826  13125     27     28     34     30        928        795
# 8    노원 총계  23201  15361     29     28     35     35        903        727
# 9    도봉 총계  12474   9144     14     15     33     36        614        618
# 10  동대문 총계  21525  15952     35     33     44     42        814        677
# ...

# %%
sns.barplot(x=data['발생 합계'], y=data['구별'], data=data)
plt.show()

# %%
sns.barplot(x=data['검거 합계'], y=data['구별'], data=data)
plt.show()

# %%
sns.barplot(x = df2_sample['cctv합계'], y=df2_sample['구별'], data=df2_sample)
plt.show()

# %%
data['검거율'] = data['검거 합계'] / data['발생 합계']

# %%
plt.subplot(1, 2, 1)
sns.barplot(x=data['검거율'], y=data['구별'], data=data)

plt.subplot(1, 2, 2)
sns.barplot(x = df2_sample['cctv합계'], y=df2_sample['구별'], data=df2_sample)
plt.show()

# %% [markdown]
# ### 결론 : 강남구와 관악구에 CCTV 예산 조정 필요
